# %% [markdown]
# ## Experimentation Accuracy RSAST per Dataset:

# %%
#configure directory to import sast libraries
import sys 
import os 
#add sast library path
file_path = os.path.expanduser("~/random_sast/sast")
sys.path.append(file_path)


sys.path
# Out:
# ['/home/nirojasvar/random_sast/ExperimentationRSAST',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python310.zip',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/lib-dynload',
#  '',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages',
#  '/home/nirojasvar/random_sast/sast',
#  '/home/nirojasvar/random_sast/sast']

# %%
from sast import *
from sktime.datasets import load_UCR_UEA_dataset, tsc_dataset_names
from sktime.classification.kernel_based import RocketClassifier
import time
import pandas as pd
# Out:
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/mass_ts/_mass_ts.py:17: UserWarning: GPU support will not work. You must pip install mass-ts[gpu].
#   warnings.warn(

# %% [markdown]
# ### Select Datasets for hypertunning RSAST

# %% [markdown]
# It is runned RSAST in a set of UCR datasets with a predefined number of runs ("runs"). Then, it is selected a range ("range_total") between [1, 10, 30 ,50,100] for the selected dataset.

# %%
ds_sens = tsc_dataset_names.univariate_equal_length

ds = pd.read_excel("DataSetsUCLASummary.xlsx")
ds = ds[ds["USED SAST"]=="Y"]
ds = ds[ds["USED RSAST ADA"].isna()]

#ds_sens = ['ACSF1', 'Adiac', 'ArrowHead', 'Beef', 'BeetleFly', 'BirdChicken', 'BME', 'Car', 'CBF', 'Chinatown', 'ChlorineConcentration', 'CinCECGTorso', 'Coffee']

ds_sens = ds.Name.unique()
ds_sens = ['SmoothSubspace', 'SonyAIBORobotSurface2', 'GunPoint',
       'ItalyPowerDemand', 'DistalPhalanxOutlineCorrect',
       'DistalPhalanxOutlineAgeGroup', 'ShapeletSim', 'SyntheticControl',
       'SonyAIBORobotSurface1', 'Chinatown', 'Coffee', 'BirdChicken']

ds_sens = ['SyntheticControl']
max_ds=len(ds_sens) #exploring dataset in UEA & UCR Time Series Classification Repository
print(max_ds)
print(ds_sens)
# Out:
# 1
# ['SyntheticControl']

# %%
#define numbers of runs of the experiment
runs = 3

#define range for number of random points and intances per class
range_exp = [1, 10, 30, 50, 100]




not_found_ds =[]

for ds in ds_sens:

    try:    
        X_train, y_train = load_UCR_UEA_dataset(name=ds, extract_path='data', split="train", return_type="numpy2d")
        X_test, y_test = load_UCR_UEA_dataset(name=ds, extract_path='data', split="test", return_type="numpy2d")
        
        print("ds="+ds)

    except:
        print("not found ds="+ds)
        not_found_ds.append(ds)
        continue

    for i in range(runs):
        df_result = {}
        list_score = []
        list_overall_time = []
        list_cweight_time = []
        list_fsubsequence_time = []
        list_tdataset_time = []
        list_tclassifier_time = []
        list_dataset = []
        list_hyperparameter = []
        list_method = []
        list_rpoint = []
        list_nb_per_class = []
        list_len_method = []
        
        for p in range_exp:

            if p ==0:
                p=1

            print("ACF&PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="both")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF&PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("ACF&PACF")
            
            print("ACF&PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="both")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF&PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("ACF&PACF")

            print("ACF&PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="both")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF&PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("ACF&PACF")


            print("ACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("ACF")
            
            print("ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("ACF")

            print("ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("ACF")

            print("PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("PACF")
            
            print("PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("PACF")

            print("PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("PACF")

            print("Max ACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="Max ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max ACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("Max ACF")


            print("Max ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="Max ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("Max ACF")

            print("Max ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="Max ACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max ACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("Max ACF")

            print("Max PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="Max PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max PACF: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("Max PACF")
            
            print("Max PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="Max PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("Max PACF")

            print("Max PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="Max PACF")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("Max PACF: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("Max PACF")

            print("None: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(n_random_points=p,half_instance=True, len_method="None")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("None: n_random_points="+str(p)+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append(str(p))
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("None")
            
            print("None: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,nb_inst_per_class=p, len_method="None")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("None: n_random_points= (lenthg ts)//2"+" nb_inst_per_class="+str(p))
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append(str(p))
            list_method.append("Rsast")
            list_len_method.append("None")

            print("None: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            start = time.time()
            random_state = None
            rsast_ridge = RSAST(half_len=True,half_instance=True, len_method="None")
            rsast_ridge.fit(X_train, y_train)
            end = time.time()
            list_score.append(rsast_ridge.score(X_test,y_test))

            list_overall_time.append(end-start)
            list_cweight_time.append(rsast_ridge.time_calculating_weights)
            list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
            list_tdataset_time.append(rsast_ridge.transform_dataset)
            list_tclassifier_time.append(rsast_ridge.time_classifier)

            list_dataset.append(ds)
            list_hyperparameter.append("None: n_random_points= (lenthg ts)//2"+" nb_inst_per_class=(max instances per class)//2")
            list_rpoint.append("(lenthg ts)//2")
            list_nb_per_class.append("(max instances per class)//2")
            list_method.append("Rsast")
            list_len_method.append("None")

        df_result['accuracy']=list_score
        df_result['time']=list_overall_time
        df_result['cweights_time']=list_cweight_time
        df_result['fsubsequence_time']=list_fsubsequence_time
        df_result['tdataset_time']=list_tdataset_time
        df_result['tclassifier_time']=list_tclassifier_time
        df_result['dataset_name']=list_dataset
        df_result['classifier_name']=list_hyperparameter
        df_result['rpoint']=list_rpoint
        df_result['nb_per_class']=list_nb_per_class
        df_result['method']=list_method
        df_result['len_method']=list_len_method
        df_result=pd.DataFrame(df_result)
        # export a overall dataset with results
        df_result.to_csv("results_accuracy_per_ds/df_overall_tunning_"+str(ds)+str(i+1)+"(extra).csv")
# Out:
# ds=SyntheticControl
# ACF&PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1439
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels1650
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43800
# ACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels406
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels510
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12000
# PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1093
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels1230
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31530
# Max ACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels14880
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels17610
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels42810
# ACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4030
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels4920
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12360
# PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels10510
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels12510
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels32760
# Max ACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels42780
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels51750
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels44760
# ACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12360
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels14670
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12180
# PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31920
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels38880
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31590
# Max ACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels70750
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels86580
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels44430
# ACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels19800
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels24240
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12210
# PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels52900
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels63450
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31410
# Max ACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels143500
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels86580
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels42480
# ACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels40300
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels24240
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12270
# PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels102100
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels63450
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31080
# Max ACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1432
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels1980
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43800
# ACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels399
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels480
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12120
# PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1049
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# RidgeClassifierCV:size training300<= kernels1410
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels32580
# Max ACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# LogisticRegressionCV:size training300> kernels150
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=1
# LogisticRegressionCV:size training300> kernels180
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels14520
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels18060
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43050
# ACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4080
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels4860
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12120
# PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels10410
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels13020
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31830
# Max ACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=10 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=10
# RidgeClassifierCV:size training300<= kernels1800
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43470
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels50730
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43920
# ACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12060
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels14670
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12180
# PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31590
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels38190
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels31830
# Max ACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=30 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=30
# RidgeClassifierCV:size training300<= kernels5400
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels72550
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels86580
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels43380
# ACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels20300
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels24240
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12240
# PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels51300
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels63450
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels32160
# Max ACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=50 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels7500
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=50
# RidgeClassifierCV:size training300<= kernels9000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels142000
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels86580
# ACF&PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels42180
# ACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels40300
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels24240
# ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels12090
# PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels107200
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels63450
# PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels30540
# Max ACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# Max ACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# Max PACF: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# Max PACF: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# None: n_random_points=100 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels15000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=100
# RidgeClassifierCV:size training300<= kernels9000
# None: n_random_points= (lenthg ts)//2 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels4500
# ACF&PACF: n_random_points=1 nb_inst_per_class=(max instances per class)//2
# RidgeClassifierCV:size training300<= kernels1430
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 51
#      49 rsast_ridge.fit(X_train, y_train)
#      50 end = time.time()
# ---> 51 list_score.append(rsast_ridge.score(X_test,y_test))
#      53 list_overall_time.append(end-start)
#      54 list_cweight_time.append(rsast_ridge.time_calculating_weights)
#
# File ~/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/base.py:666, in ClassifierMixin.score(self, X, y, sample_weight)
#     641 """
#     642 Return the mean accuracy on the given test data and labels.
#     643
#    (...)
#     662     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     663 """
#     664 from .metrics import accuracy_score
# --> 666 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~/random_sast/sast/sast.py:517, in RSAST.predict(self, X)
#     514 X = check_array(X)  # validate the shape of X
#     516 # subsequence transform of X
# --> 517 X_transformed = apply_kernels(X, self.kernels_)
#     519 return self.classifier.predict(X_transformed)
#
# File ~/anaconda3/envs/rsast_env/lib/python3.10/site-packages/numba/core/serialize.py:29, in _numba_unpickle(address, bytedata, hashed)
#      25 # Keep unpickled object via `numba_unpickle` alive.
#      26 _unpickled_memo = {}
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#      32     Parameters
#    (...)
#      41         unpickled object
#      42     """
#      43     key = (address, hashed)
#
# KeyboardInterrupt:
