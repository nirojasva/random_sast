# %% [markdown]
# ## Experimentation Accuracy RSAST per Dataset:

# %%
#configure directory to import sast libraries
import sys 
import os 
#add sast library path
file_path = os.path.expanduser("~/random_sast/sast")
sys.path.append(file_path)


sys.path
# Out:
# ['/home/nirojasvar/random_sast/ExperimentationRSAST',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python310.zip',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/lib-dynload',
#  '',
#  '/home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages',
#  '/home/nirojasvar/random_sast/sast']

# %%
from sast import *
from sktime.datasets import load_UCR_UEA_dataset, tsc_dataset_names
from sktime.classification.kernel_based import RocketClassifier
import time
import pandas as pd
# Out:
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/mass_ts/_mass_ts.py:17: UserWarning: GPU support will not work. You must pip install mass-ts[gpu].
#   warnings.warn(

# %% [markdown]
# ### Select Datasets for hypertunning RSAST

# %% [markdown]
# It is runned RSAST in a set of UCR datasets with a predefined number of runs ("runs"). Then, it is selected a range ("range_total") between [1, 10, 30 ,50,100] for the selected dataset.

# %%
ds_sens = tsc_dataset_names.univariate_equal_length

ds = pd.read_excel("DataSetsUCLASummary.xlsx")
ds = ds[ds["USED SAST"]=="Y"]
ds = ds[ds["USED RSAST ADA"].isna()]

#ds_sens = ['ACSF1', 'Adiac', 'ArrowHead', 'Beef', 'BeetleFly', 'BirdChicken', 'BME', 'Car', 'CBF', 'Chinatown', 'ChlorineConcentration', 'CinCECGTorso', 'Coffee']

ds_sens = ds.Name.unique()
ds_sens = ['SmoothSubspace', 'SonyAIBORobotSurface2', 'GunPoint',
       'ItalyPowerDemand', 'DistalPhalanxOutlineCorrect',
       'DistalPhalanxOutlineAgeGroup', 'ShapeletSim', 'SyntheticControl',
       'SonyAIBORobotSurface1', 'Chinatown', 'Coffee', 'BirdChicken']
ds_sens = ['Coffee']       
max_ds=len(ds_sens) #exploring dataset in UEA & UCR Time Series Classification Repository
print(max_ds)
print(ds_sens)
# Out:
# 1
# ['Coffee']

# %%
#define numbers of runs of the experiment
runs = 3

#define range for number of random points 
range_rpoint = [1, 10, 30, 50, 100]

#define range for number of intances per class
range_nb_inst_per_class=[1, 10, 30, 50, 100]


not_found_ds =[]

for ds in ds_sens:

    try:    
        X_train, y_train = load_UCR_UEA_dataset(name=ds, extract_path='data', split="train", return_type="numpy2d")
        X_test, y_test = load_UCR_UEA_dataset(name=ds, extract_path='data', split="test", return_type="numpy2d")
        print("ds="+ds)
    except:
        print("not found ds="+ds)
        not_found_ds.append(ds)
        continue

    for i in range(runs):
        df_result = {}
        list_score = []
        list_overall_time = []
        list_cweight_time = []
        list_fsubsequence_time = []
        list_tdataset_time = []
        list_tclassifier_time = []
        list_dataset = []
        list_hyperparameter = []
        list_method = []
        list_rpoint = []
        list_nb_per_class = []
        list_len_method = []
        
        for p in range_rpoint:
            for g in range_nb_inst_per_class:
                if p ==0:
                    p=1
                if g ==0:
                    g=1
                print("ACF&PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="both")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))

                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)

                list_dataset.append(ds)
                list_hyperparameter.append("ACF&PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("ACF&PACF")
                
                print("ACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="ACF")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))
                
                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)

                list_dataset.append(ds)
                list_hyperparameter.append("ACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("ACF")
                
                print("PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="PACF")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))
                
                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)

                list_dataset.append(ds)
                list_hyperparameter.append("PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("PACF")
                
                print("Max ACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="Max ACF")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))
                
                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)
                
                list_dataset.append(ds)
                list_hyperparameter.append("Max ACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("Max ACF")

                print("Max PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="Max PACF")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))
                
                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)
                
                list_dataset.append(ds)
                list_hyperparameter.append("Max PACF: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("Max PACF")

                print("None: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                start = time.time()
                random_state = None
                rsast_ridge = RSAST(n_random_points=p,nb_inst_per_class=g, len_method="None")
                rsast_ridge.fit(X_train, y_train)
                end = time.time()
                list_score.append(rsast_ridge.score(X_test,y_test))
                
                list_overall_time.append(end-start)
                list_cweight_time.append(rsast_ridge.time_calculating_weights)
                list_fsubsequence_time.append(rsast_ridge.time_creating_subsequences)
                list_tdataset_time.append(rsast_ridge.transform_dataset)
                list_tclassifier_time.append(rsast_ridge.time_classifier)
                
                list_dataset.append(ds)
                list_hyperparameter.append("None: n_random_points="+str(p)+" nb_inst_per_class="+str(g))
                list_rpoint.append(str(p))
                list_nb_per_class.append(str(g))
                list_method.append("Rsast")
                list_len_method.append("None")
        df_result['accuracy']=list_score
        df_result['time']=list_overall_time
        df_result['cweights_time']=list_cweight_time
        df_result['fsubsequence_time']=list_fsubsequence_time
        df_result['tdataset_time']=list_tdataset_time
        df_result['tclassifier_time']=list_tclassifier_time
        df_result['dataset_name']=list_dataset
        df_result['classifier_name']=list_hyperparameter
        df_result['rpoint']=list_rpoint
        df_result['nb_per_class']=list_nb_per_class
        df_result['method']=list_method
        df_result['len_method']=list_len_method
        df_result=pd.DataFrame(df_result)
        # export a overall dataset with results
        df_result.to_csv("results_accuracy_per_ds/df_overall_tunning_"+str(ds)+str(i+1)+"_norepTSRP.csv")
# Out:
# ds=Coffee
# ACF&PACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels136
# ACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels28
# PACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels88
# Max ACF: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# Max PACF: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# None: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# ACF&PACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels1238
# ACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels279
# PACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels915
# Max ACF: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# None: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# ACF&PACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1694
# ACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels392
# PACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1302
# Max ACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels28
# Max PACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels28
# None: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels28
# ACF&PACF: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1694
# ACF: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels392
# PACF: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1302
# Max ACF: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels28
# Max PACF: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels28
# None: n_random_points=1 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels28
# ACF&PACF: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels1694
# ACF: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels392
# PACF: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels1302
# Max ACF: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels28
# Max PACF: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels28
# None: n_random_points=1 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels28
# ACF&PACF: n_random_points=10 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels1250
# ACF: n_random_points=10 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels270
# PACF: n_random_points=10 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels1050
# Max ACF: n_random_points=10 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels20
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/nirojasvar/anaconda3/envs/rsast_env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Max PACF: n_random_points=10 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels20
# None: n_random_points=10 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels20
# ACF&PACF: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels12140
# ACF: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels2790
# PACF: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels9300
# Max ACF: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels200
# Max PACF: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels200
# None: n_random_points=10 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels38
# ACF&PACF: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels16940
# ACF: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels3920
# PACF: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels13020
# Max ACF: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels280
# Max PACF: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels280
# None: n_random_points=10 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels124
# ACF&PACF: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels16940
# ACF: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels3920
# PACF: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels13020
# Max ACF: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels280
# Max PACF: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels280
# None: n_random_points=10 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels184
# ACF&PACF: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels16940
# ACF: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels3920
# PACF: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels13020
# Max ACF: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels280
# Max PACF: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels280
# None: n_random_points=10 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels280
# ACF&PACF: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels3420
# ACF: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels840
# PACF: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels2850
# Max ACF: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels60
# Max PACF: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels60
# None: n_random_points=30 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels60
# ACF&PACF: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels35550
# ACF: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels8430
# PACF: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels27480
# Max ACF: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels600
# Max PACF: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels600
# None: n_random_points=30 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels542
# ACF&PACF: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels50820
# ACF: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels11760
# PACF: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels39060
# Max ACF: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels840
# Max PACF: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels840
# None: n_random_points=30 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels616
# ACF&PACF: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels50820
# ACF: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels11760
# PACF: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels39060
# Max ACF: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels840
# Max PACF: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels840
# None: n_random_points=30 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels745
# ACF&PACF: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels50820
# ACF: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels11760
# PACF: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels39060
# Max ACF: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels840
# Max PACF: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels840
# None: n_random_points=30 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels505
# ACF&PACF: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels7350
# ACF: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels1400
# PACF: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels4950
# Max ACF: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels100
# Max PACF: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels100
# None: n_random_points=50 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels100
# ACF&PACF: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels62550
# ACF: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels14000
# PACF: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels46450
# Max ACF: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels1000
# Max PACF: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels1000
# None: n_random_points=50 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels327
# ACF&PACF: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels84700
# ACF: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels19600
# PACF: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels65100
# Max ACF: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1400
# Max PACF: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1400
# None: n_random_points=50 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels596
# ACF&PACF: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels84700
# ACF: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels19600
# PACF: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels65100
# Max ACF: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1400
# Max PACF: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1400
# None: n_random_points=50 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1374
# ACF&PACF: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels84700
# ACF: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels19600
# PACF: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels65100
# Max ACF: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels1400
# Max PACF: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels1400
# None: n_random_points=50 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels324
# ACF&PACF: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels12400
# ACF: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels2800
# PACF: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels10900
# Max ACF: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels200
# Max PACF: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels200
# None: n_random_points=100 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels160
# ACF&PACF: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels119700
# ACF: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels28000
# PACF: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels90700
# Max ACF: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels2000
# Max PACF: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels2000
# None: n_random_points=100 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels1080
# ACF&PACF: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels169400
# ACF: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels39200
# PACF: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels130200
# Max ACF: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels2800
# Max PACF: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels2800
# None: n_random_points=100 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels672
# ACF&PACF: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels169400
# ACF: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels39200
# PACF: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels130200
# Max ACF: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels2800
# Max PACF: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels2800
# None: n_random_points=100 nb_inst_per_class=50
# RidgeClassifierCV:size training28<= kernels1257
# ACF&PACF: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels169400
# ACF: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels39200
# PACF: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels130200
# Max ACF: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels2800
# Max PACF: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels2800
# None: n_random_points=100 nb_inst_per_class=100
# RidgeClassifierCV:size training28<= kernels206
# ACF&PACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels131
# ACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels28
# PACF: n_random_points=1 nb_inst_per_class=1
# RidgeClassifierCV:size training28<= kernels99
# Max ACF: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# Max PACF: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# None: n_random_points=1 nb_inst_per_class=1
# LogisticRegressionCV:size training28> kernels2
# ACF&PACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels1174
# ACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels279
# PACF: n_random_points=1 nb_inst_per_class=10
# RidgeClassifierCV:size training28<= kernels928
# Max ACF: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# Max PACF: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# None: n_random_points=1 nb_inst_per_class=10
# LogisticRegressionCV:size training28> kernels20
# ACF&PACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1694
# ACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels392
# PACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels1302
# Max ACF: n_random_points=1 nb_inst_per_class=30
# RidgeClassifierCV:size training28<= kernels28
# Max PACF: n_random_points=1 nb_inst_per_class=30
